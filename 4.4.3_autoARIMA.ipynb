# %%
import pandas as pd
from pmdarima import auto_arima
import matplotlib.pyplot as plt

file_path = 'merged_SF.csv'
data = pd.read_csv(file_path)

data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

model = auto_arima(data['mean_ndvi_SF'], seasonal=True, m=23, trace=True)
model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[23] intercept   : AIC=-1300.382, Time=5.90 sec
#  ARIMA(0,0,0)(0,0,0)[23] intercept   : AIC=-666.241, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[23] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(0,0,1)(0,0,1)[23] intercept   : AIC=-1066.791, Time=1.81 sec
#  ARIMA(0,0,0)(0,0,0)[23]             : AIC=11.416, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,1)[23] intercept   : AIC=-1213.681, Time=4.79 sec
#  ARIMA(2,0,2)(1,0,0)[23] intercept   : AIC=-1144.790, Time=6.07 sec
#  ARIMA(2,0,2)(2,0,1)[23] intercept   : AIC=-1322.694, Time=19.26 sec
#  ARIMA(2,0,2)(2,0,0)[23] intercept   : AIC=-1331.399, Time=10.34 sec
#  ARIMA(1,0,2)(2,0,0)[23] intercept   : AIC=-1333.292, Time=10.21 sec
#  ARIMA(1,0,2)(1,0,0)[23] intercept   : AIC=-1148.516, Time=2.09 sec
#  ARIMA(1,0,2)(2,0,1)[23] intercept   : AIC=-1336.231, Time=15.68 sec
#  ARIMA(1,0,2)(1,0,1)[23] intercept   : AIC=-1342.510, Time=3.18 sec
# ...

# %%
file_path = 'merged_BD.csv'
data = pd.read_csv(file_path)

data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

model = auto_arima(data['mean_ndvi_BD'], seasonal=True, m=23, trace=True)
model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[23] intercept   : AIC=-1499.676, Time=4.37 sec
#  ARIMA(0,0,0)(0,0,0)[23] intercept   : AIC=-720.835, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[23] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(0,0,1)(0,0,1)[23] intercept   : AIC=-1179.091, Time=0.79 sec
#  ARIMA(0,0,0)(0,0,0)[23]             : AIC=12.674, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,1)[23] intercept   : AIC=-1389.530, Time=2.32 sec
#  ARIMA(2,0,2)(1,0,0)[23] intercept   : AIC=-1343.027, Time=3.24 sec
#  ARIMA(2,0,2)(2,0,1)[23] intercept   : AIC=-251.448, Time=6.80 sec
#  ARIMA(2,0,2)(1,0,2)[23] intercept   : AIC=-1466.682, Time=12.56 sec
#  ARIMA(2,0,2)(0,0,0)[23] intercept   : AIC=-1339.014, Time=0.34 sec
#  ARIMA(2,0,2)(0,0,2)[23] intercept   : AIC=-1413.293, Time=10.71 sec
#  ARIMA(2,0,2)(2,0,0)[23] intercept   : AIC=-1385.706, Time=14.60 sec
#  ARIMA(2,0,2)(2,0,2)[23] intercept   : AIC=inf, Time=14.51 sec
# ...

# %%
file_path = 'merged_FN.csv'
data = pd.read_csv(file_path)

data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

model = auto_arima(data['mean_ndvi_FN'], seasonal=True, m=23, trace=True)
model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[23] intercept   : AIC=-1476.535, Time=4.29 sec
#  ARIMA(0,0,0)(0,0,0)[23] intercept   : AIC=-724.755, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[23] intercept   : AIC=inf, Time=1.49 sec
#  ARIMA(0,0,1)(0,0,1)[23] intercept   : AIC=-1242.563, Time=1.18 sec
#  ARIMA(0,0,0)(0,0,0)[23]             : AIC=28.010, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,1)[23] intercept   : AIC=-1480.956, Time=2.29 sec
#  ARIMA(2,0,2)(0,0,0)[23] intercept   : AIC=-1409.680, Time=0.39 sec
#  ARIMA(2,0,2)(0,0,2)[23] intercept   : AIC=-1484.060, Time=10.33 sec
#  ARIMA(2,0,2)(1,0,2)[23] intercept   : AIC=-1550.852, Time=16.10 sec
#  ARIMA(2,0,2)(2,0,2)[23] intercept   : AIC=-1543.426, Time=16.41 sec
#  ARIMA(2,0,2)(2,0,1)[23] intercept   : AIC=-785.403, Time=6.56 sec
#  ARIMA(1,0,2)(1,0,2)[23] intercept   : AIC=-1521.076, Time=13.05 sec
#  ARIMA(2,0,1)(1,0,2)[23] intercept   : AIC=-1506.494, Time=8.69 sec
# ...

# %%
file_path = 'merged_FS.csv'
data = pd.read_csv(file_path)

data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

model = auto_arima(data['mean_ndvi_FS'], seasonal=True, m=23, trace=True)
model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[23] intercept   : AIC=-1220.807, Time=4.20 sec
#  ARIMA(0,0,0)(0,0,0)[23] intercept   : AIC=-366.897, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[23] intercept   : AIC=-1147.858, Time=1.46 sec
#  ARIMA(0,0,1)(0,0,1)[23] intercept   : AIC=-865.841, Time=0.57 sec
#  ARIMA(0,0,0)(0,0,0)[23]             : AIC=259.799, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,1)[23] intercept   : AIC=-1144.045, Time=2.16 sec
#  ARIMA(2,0,2)(1,0,0)[23] intercept   : AIC=-1073.093, Time=2.90 sec
#  ARIMA(2,0,2)(2,0,1)[23] intercept   : AIC=236.570, Time=3.73 sec
#  ARIMA(2,0,2)(1,0,2)[23] intercept   : AIC=-1207.355, Time=11.52 sec
#  ARIMA(2,0,2)(0,0,0)[23] intercept   : AIC=-1070.283, Time=0.34 sec
#  ARIMA(2,0,2)(0,0,2)[23] intercept   : AIC=inf, Time=10.56 sec
#  ARIMA(2,0,2)(2,0,0)[23] intercept   : AIC=-1109.536, Time=17.44 sec
#  ARIMA(2,0,2)(2,0,2)[23] intercept   : AIC=inf, Time=13.64 sec
# ...
